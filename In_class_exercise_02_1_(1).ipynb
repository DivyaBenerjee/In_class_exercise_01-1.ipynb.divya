# %% [markdown]
# <a href="https://colab.research.google.com/github/DivyaBenerjee/In_class_exercise_01-1.ipynb.divya/blob/main/In_class_exercise_02_1_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## The third In-class-exercise (02/08/2022, 40 points in total)

# %% [markdown]
# The purpose of this exercise is to understand users' information needs, then collect data from different sources for analysis.

# %% [markdown]
# Question 1 (10 points): Describe an interesting research question (or practical question) you have in mind, what kind of data should be collected to answer the question(s)? How many data needed for the analysis? The detail steps for collecting and save the data.

# %%
# Your answer here (no code for this question, write down your answer as detail as possible for the above questions):
The most recently heated up everything across the world is Covid 19. From this incident there was a lot of data collected where we can analyse it.
I thought of scrapping the varaibles like Name of the country,Continents, Deaths,Number of cases. 
The data collected from this would be in HTML and XML files which can scrapped using the below mentiones modules and libraries.
I have mentioned the flow in the below steps.

I have installed bs4 to use beautiful soup to extract data from dataset which gives information about coronavirus the countries.
This data to be extracted is in HTML format.
I have also installed module requests to make my data understandable.
I have installed texttable module to read and write the text tables and make them to look like CSV files.
From bs4 module I have imported beautiful soap library for extracting the data which is in HTML format.
Uploaded the data which is in the form of URL for scarpping the data.
Next I have got the HTML URL.
I have created a list data=[], to save the data in the list.
As a next step, I have used iter() function creates an object for the element to get repeated once in the loop.
These ojects will be useful when loops like for or while loops are used.
I have tried to create a loop where I can store the data that we required to save it. 
The loop gets repeated when ever there will be data in the iterator.
STOP ITERATION error is raised when there will be no data to be iterated.
I have used SORT function to sort the data by its number of confirmed cases.
Next I have created a texttable object and created an empty row.
I have scrapped Country, Number of cases,Deaths and Continents.

# %% [markdown]
# Question 2 (10 points): Write python code to collect 1000 data samples you discussed above.

# %%
pip install bs4

# %%
pip install requests

# %%
pip install texttable

# %%
import requests
from bs4 import BeautifulSoup
import texttable as tt

# %%
url = 'https://www.worldometers.info/coronavirus/countries-where-coronavirus-has-spread/'

# %%
page = requests.get(url)
soup = BeautifulSoup(page.text, 'html.parser')

# %%
data = []

# %%
data_iterator = iter(soup.findAll('td'))

# %%
# This loop will keep repeating till there is data available in the iterator
while True:
    try:
        country = next(data_iterator).text
        confirmed = next(data_iterator).text
        deaths = next(data_iterator).text
        continent = next(data_iterator).text
 
        # For 'confirmed' and 'deaths', make sure to remove the commas and then we will convert them to int
        data.append((
            country,
            int(confirmed.replace(',', '')),
            int(deaths.replace(',', '')),
            continent
        ))
 
    # StopIteration error is raised when there are no more elements left to iterate through
    except StopIteration:
        break

# %%
data.sort(key = lambda row: row[1], reverse = True)

# %%
covid_table = tt.Texttable()
covid_table.add_rows([(None, None, None, None)] + data)
covid_table.set_cols_align(('c', 'c', 'c', 'c')) 
covid_table.header((' Country ', ' Number of cases ', ' Deaths ', ' Continent '))
print(covid_table.draw())
# Out:
# +---------------------------+-------------------+----------+-------------------+
# |          Country          |  Number of cases  |  Deaths  |     Continent     |
# +===========================+===================+==========+===================+
# |       United States       |     79165657      |  941191  |   North America   |
# +---------------------------+-------------------+----------+-------------------+
# |           India           |     42584618      |  508012  |       Asia        |
# +---------------------------+-------------------+----------+-------------------+
# |          Brazil           |     27291515      |  637232  |   South America   |
# +---------------------------+-------------------+----------+-------------------+
# |          France           |     21503654      |  134536  |      Europe       |
# +---------------------------+-------------------+----------+-------------------+
# |      United Kingdom       |     18220515      |  159351  |      Europe       |
# ...

# %% [markdown]
# Question 3 (10 points): Write python code to collect 1000 articles from Google Scholar (https://scholar.google.com/), Microsoft Academic (https://academic.microsoft.com/home), or CiteSeerX (https://citeseerx.ist.psu.edu/index), or Semantic Scholar (https://www.semanticscholar.org/), or ACM Digital Libraries (https://dl.acm.org/) with the keyword "information retrieval". The articles should be published in the last 10 years (2012-2022).
#
# The following information of the article needs to be collected:
#
# (1) Title
#
# (2) Venue/journal/conference being published
#
# (3) Year
#
# (4) Authors
#
# (5) Abstract

# %%
pip install bs4

# %%
pip install requests

# %%
pip install texttable

# %%
import requests
from bs4 import BeautifulSoup
import texttable as tt

# %%
url= 'https://academic.microsoft.com/home'

# %%
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html dir="ltr" lang="zh-tw">
# <head data-info='{"v":"1.0.8061.4385","a":"8f56281d-ae96-4bb8-8aff-6151fa3f34c6","cn":"OneDeployContainer","az":"{did:92e7dc58ca2143cfb2c818b047cc5cd1, rid: OneDeployContainer, sn: marketingsites-prod-odeastasia, dt: 2018-05-03T20:14:23.4188992Z, bt: 2022-01-26T10:26:10.0000000Z}","ddpi":"1","dpio":"","dpi":"1","dg":"uplevel.web.pc","th":"default","m":"zh-tw","l":"zh-tw","mu":"zh-tw","rp":"/zh-tw/","f":"atperf680t2,12788c,9851t1,tasmigration010,cartemberpl,disablenorefunds,daconvertenabled,enablescarlettmetadata,redirecttogarrison,sha-exp-inlyi9j7ql","bh":{}}'>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>Microsoft – 雲端、電腦、應用程式和遊戲</title>
# <meta content="http://img-prod-cms-rt-microsoft-com.akamaized.net/cms/api/am/imageFileData/RE4OAgf?ver=6a31" name="twitter:image"/>
# ...

# %%
page = requests.get(url)
soup = BeautifulSoup(page.text, 'html.parser')

# %%
data = []

# %%
data_iterator = iter(soup.findAll('td'))

# %%
while True:
    try:
        Title = next(data_iterator).text
        Venue = next(data_iterator).text
        Years = next(data_iterator).text
        Author = next(data_iterator).text
        Content = next(data_iterator).text
 
 
        data.append((
            Title,
            int(Venue.replace(',', '')),
            int(Years.replace(',', '')),
            int(Author.replace(',','')),
            Content
        ))
 
   
    except StopIteration:
        break

# %%
data.sort(key = lambda row: row[1], reverse = True)

# %%
covid_table = tt.Texttable()
covid_table.add_rows([(None, None, None, None,None)] + data)
covid_table.set_cols_align(('c', 'c', 'c', 'c','c')) 
covid_table.header((' Title ', ' Venue ', ' Years ', ' Author ', 'Content'))
print(covid_table.draw())
# Out:
# +---------+---------+---------+----------+---------+
# |  Title  |  Venue  |  Years  |  Author  | Content |
# +=========+=========+=========+==========+=========+
# +---------+---------+---------+----------+---------+

# %% [markdown]
# Question 4 (10 points): Write python code to collect 1000 posts from Twitter, or Facebook, or Instagram. You can either use hashtags, keywords, user_name, user_id, or other information to collect the data.
#
# The following information needs to be collected:
#
# (1) User_name
#
# (2) Posted time
#
# (3) Text

# %%
def scrape():
    page = requests.get("http://dev.to")
    soup = BeautifulSoup(page.content, "html.parser")
    home = soup.find(class_="articles-list crayons-layout__content")
    posts = home.find_all(class_="crayons-story__indention")
    top_post = posts[0].find("h2", class_="crayons-story__title").text.strip()
    tweet(top_post)

# %%
def tweet(top_post):
    consumer_key = "#"
    consumer_secret = "#"
    access_token = "#"
    access_token_secret = "#"
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_token_secret)
    api = tweepy.API(auth)
    api.update_status(top_post)

scrape()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-6e68fe40afdc> in <module>()
#       9     api.update_status(top_post)
#      10
# ---> 11 scrape()
#
# <ipython-input-21-c282a971e95b> in scrape()
#       5     posts = home.find_all(class_="crayons-story__indention")
#       6     top_post = posts[0].find("h2", class_="crayons-story__title").text.strip()
# ----> 7     tweet(top_post)
#
# <ipython-input-22-6e68fe40afdc> in tweet(top_post)
#       4     access_token = "#"
#       5     access_token_secret = "#"
# ----> 6     auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
#       7     auth.set_access_token(access_token, access_token_secret)
#       8     api = tweepy.API(auth)
#
# NameError: name 'tweepy' is not defined
